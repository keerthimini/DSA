# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats

# %%
# Load data set
df=pd.read_csv(r'C:\Users\keerthi\Downloads\titanic_dataset.csv')

# %%
df # Display
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# PassengerId as the index column
df.set_index('PassengerId')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Basic details of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Fill in all the missing values present in all the columns
df1=df

# %%
df1.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Check and handle outliers in at least 3 columns in the dataset

# %%
sns.boxplot(x='Age',data=df1) # Box plot of Age
# Out:
# <Axes: xlabel='Age'>

# %%
df2=pd.read_csv(r'C:\Users\keerthi\Downloads\titanic_dataset.csv',usecols=['Age','Fare','Survived'])

# %%
df2.isnull().sum() # Finding null value
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
df2.fillna(0) #filling null value using zero
# Out:
#      Survived   Age     Fare
# 0           0  22.0   7.2500
# 1           1  38.0  71.2833
# 2           1  26.0   7.9250
# 3           1  35.0  53.1000
# 4           0  35.0   8.0500
# ..        ...   ...      ...
# 886         0  27.0  13.0000
# 887         1  19.0  30.0000
# 888         0   0.0  23.4500
# 889         1  26.0  30.0000
# 890         0  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
df2.dropna() #Droping rows with null values
# Out:
#      Survived   Age     Fare
# 0           0  22.0   7.2500
# 1           1  38.0  71.2833
# 2           1  26.0   7.9250
# 3           1  35.0  53.1000
# 4           0  35.0   8.0500
# ..        ...   ...      ...
# 885         0  39.0  29.1250
# 886         0  27.0  13.0000
# 887         1  19.0  30.0000
# 889         1  26.0  30.0000
# 890         0  32.0   7.7500
#
# [714 rows x 3 columns]

# %% [markdown]
# ### Do min max scaling on the feature set

# %%
from sklearn import datasets
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
minmax_df=pd.read_csv(r'C:\Users\keerthi\Downloads\titanic_dataset.csv')

# %%
minmax_df.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x=minmax_df.iloc[:,[2,5,6,7]]
y=minmax_df.iloc[:,1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=50)

# %%
scaler = MinMaxScaler().fit(x_train)

# %%
scaler.data_min_
# Out:
# array([1.  , 0.42, 0.  , 0.  ])

# %%
scaler.data_max_
# Out:
# array([ 3., 80.,  8.,  5.])

# %%
x_train.describe()
# Out:
#            Pclass         Age       SibSp       Parch
# count  668.000000  532.000000  668.000000  668.000000
# mean     2.275449   30.184060    0.519461    0.357784
# std      0.851242   14.430621    1.103862    0.768075
# min      1.000000    0.420000    0.000000    0.000000
# 25%      1.000000   21.000000    0.000000    0.000000
# 50%      3.000000   29.000000    0.000000    0.000000
# 75%      3.000000   39.000000    1.000000    0.000000
# max      3.000000   80.000000    8.000000    5.000000

# %%
x_train_scaled=scaler.transform(x_train)
x_train_scaled
# Out:
# array([[1.        ,        nan, 0.        , 0.        ],
#        [0.        , 0.56647399, 0.        , 0.        ],
#        [1.        ,        nan, 0.        , 0.        ],
#        ...,
#        [1.        ,        nan, 0.125     , 0.        ],
#        [1.        , 0.10781603, 0.625     , 0.4       ],
#        [1.        , 0.22090978, 0.        , 0.        ]])

# %%
test_scaler = MinMaxScaler().fit(x_test)
x_test_scaled=scaler.transform(x_test)
x_train_scaled
# Out:
# array([[1.        ,        nan, 0.        , 0.        ],
#        [0.        , 0.56647399, 0.        , 0.        ],
#        [1.        ,        nan, 0.        , 0.        ],
#        ...,
#        [1.        ,        nan, 0.125     , 0.        ],
#        [1.        , 0.10781603, 0.625     , 0.4       ],
#        [1.        , 0.22090978, 0.        , 0.        ]])
